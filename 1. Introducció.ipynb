# %% [markdown]
# # Creant jupyter notebooks

# %% [markdown]
# Amb aquesta col·lecció de documents intentem generar un material públic que ajudi a la docència a secundària

# %%
from IPython.display import FileLink, FileLinks
FileLinks('.ipynb')
# Out:
# Path (<tt>.ipynb</tt>) doesn't exist. It may still be in the process of being generated, or you may have the incorrect path.

# %%
FileLinks( "." , recursive=False)
# Out:
# ./
#   1. Introducció.ipynb
#   README.md
#   LICENSE

# %% [markdown]
# ## Per què hem escollit *jupyter notebook* ?

# %% [markdown]
# *jupyter notebook* és un entorn de treball Python (encara que pot treballar amb molts més llenguatges) amb una gran potència de càlcul i de visualització de dades, i que permet la interactivitat amb el lector.
#
# Justament la promoció que farà 1r de Batxillerat a l'institut *Príncep de Viana* és la primera promoció que va treballar amb micropython a 3r d'ESO. Per tant estaran familizaritzats amb el llenguatge de programació.
#
# Per altra banda aquests llibres interactius es podem consultar lliurament si els podem a *github* i els registrem a https://mybinder.org/
#
# A més a més amb *jupyter notebook* tenim:
# - La possibilitat d'escriure text amb la codificació Markdown, com el que esteu ara llegint
# - La possibilitat d'incloure imatges, fins-i-tot externes
# - També podem incloure vídeos
# - Podem codificar fòrmules amb Latex
# - Podem mostrar dades amb un format agradable amb HTML
# - Tenim al nostre abast funcions matemàtiques potents amb la llibreria *numpy*
# - Podem generar gràfics amb la llibreria *matplotlib*
# - Tenim accés a la llibreria  de tractament algebraic *sympy*
#
# Veiem alguns exemples:

# %% [markdown]
# ### Exemple imatge

# %%
from IPython.display import Image
img_url = 'http://www.jorts.net/PAU/dbase/img/2013-04-30-20-22-44.png'
Embed      = Image(img_url)
Embed

# %% [markdown]
# ### Exemple vídeo

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('bZ-x-zzpHTg')

# %% [markdown]
# ### Exemple fòrmula amb Latex

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# ### Exemple HTML

# %%
# %%html
# <table><tr><th>Header 1</th><th>Header 2</th></tr><tr><td>row 1, cell 1</td><td>row 1, cell 2</td></tr><tr><td>row 2, cell 1</td><td>row 2, cell 2</td></tr></table>
# Out:
# <table><tr><th>Header 1</th><th>Header 2</th></tr><tr><td>row 1, cell 1</td><td>row 1, cell 2</td></tr><tr><td>row 2, cell 1</td><td>row 2, cell 2</td></tr></table>

# %% [markdown]
# ### Exemple gràfica

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 300)
y = np.sin(x**2)
plt.plot(x, y)
plt.title("A little chirp")
fig = plt.gcf()

# %% [markdown]
# ### Exemple algebraic

# %%
from IPython.display import display
from sympy.interactive import printing
printing.init_printing(use_latex='mathjax')
from sympy import *
x, y, z = symbols("x y z")

eq = ((x+y)**2 * (x+1))
eq
# Out:
#                2
# (x + 1)⋅(x + y)

# %%
expand(eq)
# Out:
#  3      2      2      2            2
# x  + 2⋅x ⋅y + x  + x⋅y  + 2⋅x⋅y + y

# %%
eq = Eq(x**3 - 8*x**2 + 5*x + 14, 0)
eq
# Out:
#  3      2
# x  - 8⋅x  + 5⋅x + 14 = 0

# %%
solve(eq, x)
# Out:
# [-1, 2, 7]
